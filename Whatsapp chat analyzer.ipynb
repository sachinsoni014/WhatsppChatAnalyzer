# %%
import re
import pandas as pd

# %%
file = open('WhatsappchatFriends.txt','r', encoding='utf-8')

# %%
whatsppdata = file.read()

# %%
print(whatsppdata)
# Out:
# 2/14/21, 10:50 AM - Sachin soni😎: Ni pata reyy 1st time dekh rha 🤣
# 2/14/21, 10:50 AM - Aboli New: Ye pyaz ka phool h...maine b phli baar hi dekha
# 2/14/21, 10:52 AM - Sachin soni😎: Omg 😮
# 2/14/21, 10:53 AM - Aboli New: Yoo...ye payz k patto pr lgta h...abi ye dry krke isase beej nikalenge
# 2/14/21, 12:21 PM - Sachin soni😎: <Media omitted>
# 2/14/21, 10:35 PM - Bhuppi: Gaga tuje yaad hai
# 2/14/21, 10:35 PM - Bhuppi: aaj hum log tehalka gye the
# 2/14/21, 10:36 PM - Bhuppi: And tune waiter ko hadkaya tha
# 2/14/21, 10:36 PM - Bhuppi: Nd ladai krai thi unki
# 2/14/21, 10:42 PM - Aboli New: <Media omitted>
# 2/14/21, 10:47 PM - Sachin soni😎: Haan yaad hai 🤣 humne rating bhi masstt and reviews masstt diye the 🤣😂
# 2/14/21, 10:48 PM - Bhuppi: Gaga tera bday aara hah
# 2/14/21, 10:48 PM - Bhuppi: Kya khaayega goo k elaava?
# 2/14/21, 10:48 PM - Sachin soni😎: Hao 😷
# 2/14/21, 10:48 PM - Bhuppi: Kya chahiye tuje
# 2/14/21, 10:48 PM - Sachin soni😎: 😒
# ...

# %%
pattern = '\d{1,2}/\d{1,2}/\d{1,2},\s1[012]:[0-5][0-9]|1[1-9]:[0-5][0-9]'

# %%
messages = re.split(whatsppdata, pattern)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-8-754d1c0b9c2a> in <module>
# ----> 1 messages = re.split(whatsppdata, pattern)
#
# ~\anaconda3\lib\re.py in split(pattern, string, maxsplit, flags)
#     229     and the remainder of the string is returned as the final element
#     230     of the list."""
# --> 231     return _compile(pattern, flags).split(string, maxsplit)
#     232
#     233 def findall(pattern, string, flags=0):
#
# ~\anaconda3\lib\re.py in _compile(pattern, flags)
#     302     if not sre_compile.isstring(pattern):
#     303         raise TypeError("first argument must be string or compiled pattern")
# --> 304     p = sre_compile.compile(pattern, flags)
#     305     if not (flags & DEBUG):
#     306         if len(_cache) >= _MAXCACHE:
#
# ~\anaconda3\lib\sre_compile.py in compile(p, flags)
#     762     if isstring(p):
# ...

# %%
print(messages)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-0583f9d907b2> in <module>
# ----> 1 print(messages)
#
# NameError: name 'messages' is not defined

# %%
dates = re.findall(whatsppdata, pattern)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-45-30dc7e7d4dbe> in <module>
# ----> 1 dates = re.findall(whatsppdata, pattern)
#
# ~\anaconda3\lib\re.py in findall(pattern, string, flags)
#     239
#     240     Empty matches are included in the result."""
# --> 241     return _compile(pattern, flags).findall(string)
#     242
#     243 def finditer(pattern, string, flags=0):
#
# ~\anaconda3\lib\re.py in _compile(pattern, flags)
#     302     if not sre_compile.isstring(pattern):
#     303         raise TypeError("first argument must be string or compiled pattern")
# --> 304     p = sre_compile.compile(pattern, flags)
#     305     if not (flags & DEBUG):
#     306         if len(_cache) >= _MAXCACHE:
#
# ~\anaconda3\lib\sre_compile.py in compile(p, flags)
#     762     if isstring(p):
#     763         pattern = p
# ...
